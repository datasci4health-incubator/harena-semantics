# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = [[2743, 1, 148, 153, 0, 9, 1562], [0, 4695, 23, 0, 9, 0, 651], [111, 29, 3438, 3, 0, 80, 763], [515, 0, 14, 1886, 0, 72, 756], [0, 588, 0, 0, 661, 0, 379], [17, 4, 656, 61, 0, 1260, 739], [668, 1177, 1239, 326, 362, 290, 198622]]
df_cm = pd.DataFrame(array, index = [i for i in ['B-Anatomy', 'B-Chemical', 'B-Disease', 'I-Anatomy', 'I-Chemical', 'I-Disease', 'O']],
              columns = [i for i in ['B-Anatomy', 'B-Chemical', 'B-Disease', 'I-Anatomy', 'I-Chemical', 'I-Disease', 'O']])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, cmap="Blues", vmax=5000)
# Out:
# <AxesSubplot:>

# %%
array = [[5135, 10, 33, 1, 206], [16, 3966, 0, 174, 268], [30, 0, 1450, 0, 148], [4, 116, 1, 2335, 281], [227, 440, 231, 367, 109311]]
df_cm = pd.DataFrame(array, index = [i for i in ['B-Disease', 'B-Quemical', 'I-Disease', 'I-Quemical', 'O']],
              columns = [i for i in ['B-Disease', 'B-Quemical', 'I-Disease', 'I-Quemical', 'O']])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, cmap="Blues", vmax=2000)
# Out:
# <AxesSubplot:>

# %%
array = [[886, 38, 36], [15, 1026, 46], [100, 100, 22250]]
df_cm = pd.DataFrame(array, index = [i for i in ['B-Disease', 'I-Disease', 'O']],
              columns = [i for i in ['B-Disease', 'I-Disease', 'O']])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, cmap="Blues", vmax=2000)
# Out:
# <AxesSubplot:>

# %%
# lr = 5e-04
array = [[0, 0, 960], [0, 0, 1087], [0, 0, 22450]]
df_cm = pd.DataFrame(array, index = [i for i in ['B-Disease', 'I-Disease', 'O']],
              columns = [i for i in ['B-Disease', 'I-Disease', 'O']])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, cmap="Blues", vmax=2000)
# Out:
# <AxesSubplot:>
